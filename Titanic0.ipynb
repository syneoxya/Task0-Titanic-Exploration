# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
d1=pd.read_csv('/content/drive/MyDrive/DAC/train.csv')
d1
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
d1.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
d1.shape
# Out:
# (891, 12)

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
d1 = d1.dropna(how='any',axis=0)

# %%
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    int64
#  1   Survived     183 non-null    int64
#  2   Pclass       183 non-null    int64
#  3   Name         183 non-null    object
#  4   Sex          183 non-null    object
#  5   Age          183 non-null    float64
#  6   SibSp        183 non-null    int64
#  7   Parch        183 non-null    int64
#  8   Ticket       183 non-null    object
#  9   Fare         183 non-null    float64
#  10  Cabin        183 non-null    object
#  11  Embarked     183 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 18.6+ KB

# %%
d1.drop(['PassengerId','Name'],axis=1)
# Out:
#      Survived  Pclass     Sex   Age  ...    Ticket     Fare        Cabin  Embarked
# 1           1       1  female  38.0  ...  PC 17599  71.2833          C85         C
# 3           1       1  female  35.0  ...    113803  53.1000         C123         S
# 6           0       1    male  54.0  ...     17463  51.8625          E46         S
# 10          1       3  female   4.0  ...   PP 9549  16.7000           G6         S
# 11          1       1  female  58.0  ...    113783  26.5500         C103         S
# ..        ...     ...     ...   ...  ...       ...      ...          ...       ...
# 871         1       1  female  47.0  ...     11751  52.5542          D35         S
# 872         0       1    male  33.0  ...       695   5.0000  B51 B53 B55         S
# 879         1       1  female  56.0  ...     11767  83.1583          C50         C
# 887         1       1  female  19.0  ...    112053  30.0000          B42         S
# ...

# %%
d1.head()
# Out:
#     PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 1             2         1       1  ...  71.2833   C85         C
# 3             4         1       1  ...  53.1000  C123         S
# 6             7         0       1  ...  51.8625   E46         S
# 10           11         1       3  ...  16.7000    G6         S
# 11           12         1       1  ...  26.5500  C103         S
#
# [5 rows x 12 columns]

# %%
d1=d1.reset_index(drop=True)
d1
# Out:
#      PassengerId  Survived  Pclass  ...     Fare        Cabin  Embarked
# 0              2         1       1  ...  71.2833          C85         C
# 1              4         1       1  ...  53.1000         C123         S
# 2              7         0       1  ...  51.8625          E46         S
# 3             11         1       3  ...  16.7000           G6         S
# 4             12         1       1  ...  26.5500         C103         S
# ..           ...       ...     ...  ...      ...          ...       ...
# 178          872         1       1  ...  52.5542          D35         S
# 179          873         0       1  ...   5.0000  B51 B53 B55         S
# 180          880         1       1  ...  83.1583          C50         C
# 181          888         1       1  ...  30.0000          B42         S
# 182          890         1       1  ...  30.0000         C148         C
#
# [183 rows x 12 columns]

# %%
d2=d1.iloc[0:146]
d2
# Out:
#      PassengerId  Survived  Pclass  ...      Fare    Cabin  Embarked
# 0              2         1       1  ...   71.2833      C85         C
# 1              4         1       1  ...   53.1000     C123         S
# 2              7         0       1  ...   51.8625      E46         S
# 3             11         1       3  ...   16.7000       G6         S
# 4             12         1       1  ...   26.5500     C103         S
# ..           ...       ...     ...  ...       ...      ...       ...
# 141          699         0       1  ...  110.8833      C68         C
# 142          700         0       3  ...    7.6500    F G63         S
# 143          701         1       1  ...  227.5250  C62 C64         C
# 144          702         1       1  ...   26.2875      E24         S
# 145          708         1       1  ...   26.2875      E24         S
#
# [146 rows x 12 columns]

# %%
d3=d1.iloc[146:183]
d3
# Out:
#      PassengerId  Survived  Pclass  ...      Fare            Cabin  Embarked
# 146          711         1       1  ...   49.5042              C90         C
# 147          713         1       1  ...   52.0000             C126         S
# 148          716         0       3  ...    7.6500            F G73         S
# 149          717         1       1  ...  227.5250              C45         C
# 150          718         1       2  ...   10.5000             E101         S
# 151          725         1       1  ...   53.1000               E8         S
# 152          731         1       1  ...  211.3375               B5         S
# 153          738         1       1  ...  512.3292             B101         C
# 154          742         0       1  ...   78.8500              C46         S
# 155          743         1       1  ...  262.3750  B57 B59 B63 B66         C
# 156          746         0       1  ...   71.0000              B22         S
# ...

# %%
d1.hist('Age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9ca73c9390>]],
#       dtype=object)

# %%
d1.hist('Fare')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9ca6e4c210>]],
#       dtype=object)

# %%
total_survived=d1[d1['Survived']==1]
len(total_survived)
# Out:
# 123

# %%
total_dead=d1[d1['Survived']==0]
len(total_dead)
# Out:
# 60

# %%
d={'Suvived':[len(total_survived)],'Died':[len(total_dead)]}
d4=pd.DataFrame(data=d)
d4
# Out:
#    Suvived  Died
# 0      123    60

# %%
b=d4.plot.bar()
